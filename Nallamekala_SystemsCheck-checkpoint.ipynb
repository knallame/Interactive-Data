# %% [markdown]
# # Systems Check
#
# ## Keerthi Priya Nallamekala

# %% [markdown]
# # Heading 1
#
# ## Heading 2
#
# **Bold Sentence**
#
# *Italic*
#
#
# Interactive data allows us to:
#
# 1. **Explore Data More Deeply:** It enables you to engage with the data dynamically, allowing you to uncover patterns, trends, and insights that might be missed with static analysis.
#
# 2. **Enhance Understanding:** By interacting with the data, you can manipulate variables and filters to see how changes affect outcomes, leading to a deeper comprehension of the data.
#
# 3. **Make Data-Driven Decisions:** Interactive data visualizations can help in making informed decisions by providing a clear, real-time view of the data, which is crucial for identifying key insights.
#
# 4. **Improve Communication:** Interactive data tools allow for better communication of findings, as stakeholders can explore the data themselves, leading to more effective discussions and decision-making.

# %% [markdown]
# ![Image](data:image/jpeg;base64,...)

# %%
# Variable Assignment
A='Keerthi'

# %%
print(A)
# Out:
# Keerthi

# %%
My_List=[1,2,3,4,5]

# %%
My_List[3]
# Out:
# 4

# %%
# For for loop
fruits = ["Mango", "Apple", "Banana"]
for x in fruits:
  print(x)
# Out:
# Mango
# Apple
# Banana

# %% [markdown]
# I used "for" loop to print each fruit in a fruit list.

# %%
# Function with print statement and return statement
def display_name(X):
    print(X)

# %%
display_name(A)
# Out:
# Keerthi

# %%
def change_name(A):
    new_name=A+" Priya"
    return new_name

# %%
change_name(A)
# Out:
# 'Keerthi Priya'
