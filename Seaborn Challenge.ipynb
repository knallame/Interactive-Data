# %% [markdown]
# ## Week-5 Group 1-Seaborn Challenge

# %%
import pandas as pd
import seaborn as sns

# %%
titanic = pd.read_csv('titanic_clean.csv')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age     fare embarked    who  embark_town alive  \
# 0         0       3    male  22.0   7.2500        S    man  Southampton    no
# 1         1       1  female  38.0  71.2833        C  woman    Cherbourg   yes
# 2         1       3  female  26.0   7.9250        S  woman  Southampton   yes
# 3         1       1  female  35.0  53.1000        S  woman  Southampton   yes
# 4         0       3    male  35.0   8.0500        S    man  Southampton    no
#
#    alone
# 0  False
# 1  False
# 2   True
# 3  False
# 4   True

# %%
sns.relplot(data=titanic, x="age", y="fare")

# %%
sns.relplot(data=titanic, x="age", y="fare", alpha=0.5) 
# alpha ranges from 0-1

# %%
sns.relplot(data=titanic, x="age", y="fare", alpha=0.5,hue="sex")

# %%
sns.relplot(data=titanic, x="age", y="fare", alpha=0.5, hue="sex",col='survived')

# %%
sns.relplot(data=titanic, x="age", y="fare", alpha=0.5, hue="sex", col='survived', palette={"male":"blue","female":"magenta"})

# %%
titanic['Sex'] = titanic['sex'].map({"male":"Male", "female":"Female"})
sns.relplot(data=titanic, x="age", y="fare", alpha=0.5, hue="Sex", col='survived', palette={"Male":"blue","Female":"magenta"})

# %%
titanic['Sex'] = titanic['sex'].map({"male":"Male", "female":"Female"})
sns.relplot(data=titanic, x="age", y="fare", alpha=0.5, hue="Sex", col='survived', palette={"Male":"blue","Female":"magenta"},size='pclass')

# %%
titanic['survived_ind'] = titanic['survived'].map({0:"did not survive", 1:"Survive"})
sns.relplot(data=titanic, x="age", y="fare", alpha=0.5, hue="survived_ind", col='survived', palette={"did not survive":"#3A0CA3","Survive":"#ffbd33"})

# %%
titanic['survived_ind'] = titanic['survived'].map({0:"did not survive", 1:"Survive"})
sns.relplot(data=titanic, x="age", y="fare", alpha=0.5, hue="survived_ind", col='survived', palette={"did not survive":"#3A0CA3","Survive":"#ffbd33"},size='pclass')

# %% [markdown]
# ## Week-5 Group 2-Seaborn Challenge

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
smh = pd.read_csv("Student Mental health.csv")
smh.head()
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# ...

# %%
smh.groupby("Choose your gender")[['Do you have Depression?','Do you have Anxiety?','Do you have Panic attack?']].count()
# Out:
#                     Do you have Depression?  Do you have Anxiety?  \
# Choose your gender
# Female                                   75                    75
# Male                                     26                    26
#
#                     Do you have Panic attack?
# Choose your gender
# Female                                     75
# Male                                       26

# %%
columns_to_plot = smh.columns[-4:-1]
category_order = ["Yes","No"]

# %%
for column in columns_to_plot:
    counts = smh[column].value_counts()
    counts = counts.reindex(category_order, fill_value=0)
    print(counts)
    print()
# Out:
# Do you have Depression?
# Yes    35
# No     66
# Name: count, dtype: int64
#
# Do you have Anxiety?
# Yes    34
# No     67
# Name: count, dtype: int64
#
# Do you have Panic attack?
# Yes    33
# No     68
# Name: count, dtype: int64

# %%
sns.countplot(smh, x="Do you have Depression?", stat='percent', hue='Did you seek any specialist for a treatment?')
# Out:
# <Axes: xlabel='Do you have Depression?', ylabel='percent'>

# %%
sns.countplot(smh, x="Do you have Anxiety?", stat='percent', hue='Did you seek any specialist for a treatment?')
# Out:
# <Axes: xlabel='Do you have Anxiety?', ylabel='percent'>

# %%
sns.countplot(smh, x="Do you have Panic attack?", stat='percent', hue='Did you seek any specialist for a treatment?')
# Out:
# <Axes: xlabel='Do you have Panic attack?', ylabel='percent'>

# %%
sns.countplot(smh, x="Do you have Depression?", stat='percent', hue='Choose your gender', palette='PuBuGn')
# Out:
# <Axes: xlabel='Do you have Depression?', ylabel='percent'>

# %%
sns.countplot(smh, x="Do you have Anxiety?", stat='percent', hue='Choose your gender', palette='PuBuGn')
# Out:
# <Axes: xlabel='Do you have Anxiety?', ylabel='percent'>

# %%
sns.countplot(smh, x="Do you have Panic attack?", stat='percent', hue='Choose your gender', palette='PuBuGn')
# Out:
# <Axes: xlabel='Do you have Panic attack?', ylabel='percent'>
